# %%
from thinkdsp import read_wave
wave = read_wave('glissando.wav')
wave = wave.segment(0.5, 1.5)
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.make_spectrogram(512).plot(high=6000)

# %% [markdown]
# Ввиду невозможности скачать требуемый файл, используется выбранный в интернете. На рисунке выше видно, что спектрограмма не совсем совпадает со спекторграммой чипа, полученной ранее, но схожести увидеть можно
