# %%
# Get thinkdsp.py

import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %%
from thinkdsp import read_wave, decorate
filename = '252798__oymaldonado__movie-score-classical-music-loop-part-1.wav'

# %%
def stretch(wave, factor):
    wave.ts /= factor
    wave.framerate *= factor
    return wave

# %%
wave = read_wave(filename)
start = 41.2
duration = 0.5
segment = wave.segment(start, duration)
segment.plot()
decorate(xlabel='Time (s)')

# %%
segment.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Изменим сигнал по заданию и проверим, что получится

# %%
segment = stretch(segment, 0.2)
segment.plot()
decorate(xlabel='Time (s)')

# %%
segment.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Сигнал получился в 5 раз дольше
